# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\jaisw\Downloads\data.csv")
df.head(5)
# Out:
#           Car       Model  Volume  Weight  CO2
# 0      Toyoty        Aygo    1000     790   99
# 1  Mitsubishi  Space Star    1200    1160   95
# 2       Skoda      Citigo    1000     929   95
# 3        Fiat         500     900     865   90
# 4        Mini      Cooper    1500    1140  105

# %%
x = df[['Weight', 'Volume']]
y = df['CO2']

# %%
from sklearn import linear_model
regr = linear_model.LinearRegression()
regr.fit(X, y)
# Out:
# LinearRegression()

# %%
#predict the CO2 emission of a car where the weight is 2300kg, and the volume is 1300cm3:
predictedCO2 = regr.predict([[2300, 1300]])
# Out:
# C:\Users\jaisw\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
print(predictedCO2)
# Out:
# [107.2087328]

# %%
print(regr.coef_)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 print(regr.coef_)
#
# NameError: name 'regr' is not defined

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\jaisw\OneDrive\Desktop\CSE 2\SEM2_CSE2\ADS\Advertising_Regression.csv")

# %%
#plot
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D


fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

X = df[['TV', 'radio']]
y = df['sales']

ax.scatter(X['TV'], X['radio'], y, color='blue', label='Actual data')

tv_range = np.linspace(X['TV'].min(), X['TV'].max(), 10)
radio_range = np.linspace(X['radio'].min(), X['radio'].max(), 10)
tv_grid, radio_grid = np.meshgrid(tv_range, radio_range)
pred = regr.predict(np.c_[tv_grid.ravel(), radio_grid.ravel()])
pred = pred.reshape(tv_grid.shape)

ax.plot_surface(tv_grid, radio_grid, pred, color='orange', alpha=0.5, label='Regression plane')

ax.set_xlabel('TV')
ax.set_ylabel('Radio')
ax.set_zlabel('Sales')
ax.set_title('3D Scatter Plot with Regression Plane')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 14
#      10 y = df['sales']
#      12 ax.scatter(X['TV'], X['radio'], y, color='blue', label='Actual data')
# ---> 14 tv_range = np.linspace(X['TV'].min(), X['TV'].max(), 10)
#      15 radio_range = np.linspace(X['radio'].min(), X['radio'].max(), 10)
#      16 tv_grid, radio_grid = np.meshgrid(tv_range, radio_range)
#
# NameError: name 'np' is not defined
